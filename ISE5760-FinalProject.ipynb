# %%
# Maximizing Damage Output for a D&D character 

# There is much variablility in D&D, so we decided to control many variables that can be adjusted.
# The assumed Race is Human and any additional feats are assumed to be Ability Score Increase (ASI)
# To that end, the assumed stats of the characters is 18 in the main stat (Str or Dex), then 16 and 14
# Armor class for enemies has been set to 13. Chance to hit = 1 - (AC-bonus_to_hit)/20
# Reminder: Crits only double damage on dice, not the modifiers.

import cvxpy as cp

AC = 13
subclass = cp.Variable(7, b
                       (4, boolean = True) # Fighting style

# Not sure if this is most clear way to implement
crit = if (subclass[0] == 1) 2/20 else 1/20

obj_func=

constraints = []
# Ensures only one subclass's set of actions can be used
constraints.append(subclass[0] + subclass[1] + subclass[2] + subclass[3] + 
                   subclass[4] + subclass[5] + subclass[6] == 1)

# Actions available to Fighter; Champion
 # 2x attack w/ Archery - Heavy Cross-bow
constraints.append(subclass[0]*fighting_style[0]*(2*(1-(AC-9)/20))(9.5)+2*(2/20)(5.5))
 # 2x attack w/ Dueling - Long Sword
constraints.append(subclass[0]*fighting_style[1]*(2*(1-(AC-7)/20))(10.5)+2*(2/20)(4.5))
 # 2x attack w/ Great Weapon Fighting - Greatsword
constraints.append(subclass[0]*fighting_style[2]*(2*(1-(AC-7)/20))(11)+2*(2/20)(7))
 # 2x attack w/ Two-Weapon Fighting 
constraints.append(subclass[0]*fighting_style[3]*(2*(1-(AC-7)/20))(7.5)+2*(2/20)(3.5))
 # Bonus attack w/ Two-Weapon Fighting
constraints.append(subclass[0]*fighting_style[3]*(1-(AC-7)/20)(7.5)+(2/20)(3.5))

    1 - (AC- PB+AB)/20 * WP+AB + crit*WP
            STR DEX
                       
# Actions available to Fighter; Battlemaster (has 4 superiority dice (SD; 1d8) thus always applied)
# The best maneuver for damage is the Feinting Attack (FA also gives advantage)
# Note, FA also uses bonus action, so the only SD is added for Two-Weapon/Ranged Fighters
 # 2x attack w/ Archery - Heavy Cross-bow (one with SD)
constraints.append(subclass[1]*fighting_style[0]*(1-(AC-9)/20)(14)+(1/20)(10))
constraints.append(subclass[1]*fighting_style[0]*(1-(AC-9)/20)(9.5)+(1/20)(5.5))
 # 2x attack w/ Dueling - Long Sword (one with Feinting SD)
constraints.append(subclass[1]*fighting_style[1]*(1-2*(AC-7)/20)(15)+2*(1/20)(9))
constraints.append(subclass[1]*fighting_style[1]*(1-(AC-7)/20))(10.5)+(1/20)(4.5)
 # 2x attack w/ Great Weapon Fighting - Greatsword (one with Feinting SD)
constraints.append(subclass[1]*fighting_style[2]*(1-2*(AC-7)/20)(15.5)+2*(1/20)(11.5))
constraints.append(subclass[1]*fighting_style[2]*(1-(AC-7)/20))(11.5)+(1/20)(7)
 # 2x attack w/ Two-Weapon Fighting (one with SD)
constraints.append(subclass[1]*fighting_style[3]*(1-(AC-7)/20)(12)+(1/20)(8))
constraints.append(subclass[1]*fighting_style[3]*(1-(AC-7)/20)(7.5)+(1/20)(3.5))
 # Bonus attack w/ Two-Weapon Fighting
constraints.append(subclass[1]*fighting_style[3]*(1-(AC-7)/20)(7.5)+(2/20)(3.5))

# Actions available to Barbarian; Berserker (Greatsword is best for DPS)
constraints.append(subclass[2]*(2*(1-2*(AC-7)/20)*(11.5)+2*(2/20)(7)

# Actions available to Monks in gereral (has 4 ki-points thus always applied)
 # 2x attack w/ quarterstaff
constraints.append(subclass[3]*(2*(1-(AC-7)/20))(7.5)+2*(1/20)(7.5))
 # Flurry of Blows (bonus_action)
constraints.append(subclass[3]*(2*(1-(AC-7)/20)(3.5)+2*(1/20)*3.5)
    
# Actions available to Ranger; Hunter (Hunter's Prey = Colossus Slayer ~ +1d8)
 # 2x attack w/ Archery - Heavy Cross-bow
constraints.append(subclass[4]*fighting_style[0]*(1-(AC-9)/20)(14)+(1/20)(10))
constraints.append(subclass[4]*fighting_style[0]*(1-(AC-9)/20)(9.5)+(1/20)(5.5))
 # 2x attack w/ Dueling - Long Sword 
constraints.append(subclass[4]*fighting_style[1]*(1-(AC-7)/20)(15)+(1/20)(9))
constraints.append(subclass[4]*fighting_style[1]*(1-(AC-7)/20))(10.5)+(1/20)(4.5)
 # 2x attack w/ Two-Weapon Fighting (one with SD)
constraints.append(subclass[4]*fighting_style[3]*(1-(AC-7)/20)(12)+(1/20)(8))
constraints.append(subclass[4]*fighting_style[3]*(1-(AC-7)/20)(7.5)+(1/20)(3.5))
 # Bonus attack w/ Two-Weapon Fighting
constraints.append(subclass[4]*fighting_style[3]*(1-(AC-7)/20)(7.5)+(2/20)(3.5))

# Actions available to Ranger; Beast Master
 # 2x attack w/ Archery - Heavy Cross-bow
constraints.append(subclass[1]*fighting_style[0]*(2*(1-(AC-9)/20)(9.5)+2*(1/20)(5.5))
 # 2x attack w/ Dueling - Long Sword
constraints.append(subclass[1]*fighting_style[1]*(2*(1-(AC-7)/20))(10.5)+2*(1/20)(4.5)
 # 2x attack w/ Two-Weapon Fighting
constraints.append(subclass[1]*fighting_style[3]*(2*(1-(AC-7)/20)(7.5)+2*(1/20)(3.5))
 # Bonus attack w/ Two-Weapon Fighting
constraints.append(subclass[1]*fighting_style[3]*(1-(AC-7)/20)(7.5)+(2/20)(3.5))
 # Bonus Attack for beast of Land~ (alternative rules are more efficient TCoE)
constraints.append(subclass[1]*(1-(AC-7)/20)(8.5)+(1/20)(4.5)) # Beast of Land
                   
### Actions available to Rogue; Assassin ###
 # hide (assumed success) for advantage; sneak attack + rapier;
constraints.append(subclass[6]*((1-2*(AC-7)/20))*(10.5 + 8.5)+(2/20)*(15)) 
 # sneak attack + off-hand;
constraints.append(subclass[6]*((1-(AC-7)/20))*(10.5 + 8.5)+(1/20)*(15)+(1-(AC-7)/20)*(4.5)+(1/20)*4.5)

                   
problem = cp.Problem(cp.Maximize(obj_func), constraints)

problem.solve(solver=cp.GUROBI,verbose = False)

print("obj_func =")
print(obj_func.value)
print("subclass =")
print(subclass.value)
print("Bonus Action =")
print(bonus_action.value)
# Out:
#   Cell In[1], line 17
#     crit = if (subclass[0] == 1) 2/20 else 1/20
#            ^
# SyntaxError: invalid syntax
